# %% [markdown]
# # Purdue University Professional Certificate in AI and Machine Learning
#
# Content I want to share from this course
#
# * [Programming Refresher - Python and Jupyter Notebooks](./programming_refresher/index.ipynb#readme)
