# %% [markdown]
# <a id='readme'></a>
# ## What's here
#
# Things I experimented with from the Programming Refresher

# %%
from hello import super_adder

super_adder(4, 5, 6, 7)
# Out:
# 22

# %%
string: str = "Hello"  # I have added a type annotation here, this is not required
print(string)
string
# Out:
# Hello
# 'Hello'

# %%
another_string = "I am another string"  # No type annotation here, I let Python figure it out
print(another_string)
another_string
# Out:
# I am another string
# 'I am another string'

# %%
strings: list[str] = ["one", "two", "three"]
print(strings)
strings
# Out:
# ['one', 'two', 'three']
# ['one', 'two', 'three']

# %%
strings = ["one", "two", "three"]
print(strings)
strings
# Out:
# ['one', 'two', 'three']
# ['one', 'two', 'three']

# %%
a = ['a', 'b', 'c']
b = ['a', 'b', 'c']
print(a is b)
print(a == b)
a is b
# Out:
# False
# True
# False

# %%
a = ('a', 'b', 'c')
b = ('a', 'b', 'c')
print(a is b)
print(a == b)
a is b
# Out:
# False
# True
# False

# %%
a = ['a', 'b', 'c']
b = ('a', 'b', 'c')
print(a is b)
print(a == b)
a is b
# Out:
# False
# False
# False
